# %% [markdown]
# ### Demonstrate Genetic Algorithm by taking a suitable data for any simple application
# ### The target string is "HELLO, WORLD!" and we want to evolve a population of random strings to eventually produce this target string.

# %%
import random
import string

target = "HELLO, WORLD!"

ps = 200
mr = 0.01

def generate_random_string(length):
    return ''.join(random.choice(string.printable) for _ in range(length))

def calculate_fitness(string):
    return sum(1 for a, b in zip(string, target) if a == b)

def select(population):
    total_fitness = sum(calculate_fitness(ind) for ind in population)
    r = random.uniform(0, total_fitness)
    current_sum = 0
    for ind in population:
        current_sum += calculate_fitness(ind)
        if current_sum >= r:
            return ind

def create_new_generation(population):
    new_population = []
    for _ in range(ps):
        parent1 = select(population)
        parent2 = select(population)
        split_point = random.randint(1, len(target) - 1)
        child = parent1[:split_point] + parent2[split_point:]
        for i in range(len(child)):
            if random.random() < mr:
                child = child[:i] + random.choice(string.printable) + child[i+1:]
        new_population.append(child)
    return new_population

population = [generate_random_string(len(target)) for _ in range(ps)]
generation = 1

while True:
    population.sort(key=lambda x: -calculate_fitness(x))
    best_individual = population[0]
    print(f"Generation {generation}: {best_individual}")
    if best_individual == target:
        break
    population = create_new_generation(population)
    generation += 1
# Out:
# Generation 1: _{0Ch_5WO|$h2
# Generation 2: H>BS{_5WO|$h2
# Generation 3: 9F"L	_5WO|*~!
# Generation 4: H>HhO`5WO|$h2
# Generation 5: HPcS-x WOG]se
# Generation 6: H>HhO%-WO@*~!
# Generation 7: H>HhO% Wm0w~!
# Generation 8: H>HhO% WO|$D`
# Generation 9: H>HhO% WO|$D!
# Generation 10: H>yDOK xORwD$
# Generation 11: H>0hO, WO|wD`
# Generation 12: H>0LOK xORw~!
# D`neration 13: aP0LO, WO|
# RwD!ration 14: HP0LOr O
# Generation 15: UE6LOZ WO|!~!
# Generation 16: H>HLO, WO|wDM
# Generation 17: H>HLO, WO|wD$
# Generation 18: HEHLO, WexVD`
# Generation 19: HEHLO, WO||m!
# Generation 20: HEHLO, WO||D!
# Generation 21: HEHLO, WO||D!
# Generation 22: HEHLO, WO||D!
# Generation 23: HEHLO, WO||D!
# Generation 24: HFuLO, WORhD!
# Generation 25: HFuLO, WORhD!
# Generation 26: HEHLO, WO||D!
# Generation 27: HEHLO, WOR{Dp
# Generation 28: HFuLO, WORwD!
# D!neration 29: HP0LO, WOR
# D!O, WORon 30: H
# Generation 31: HEHLO, WO|wD!
# Generation 32: HFSLO, WORwD!
# Generation 33: HESLO, WOR*D!
# D!neration 34: HESLO, WOR
# D!neration 35: Ha0LO, WOR
# D!neration 36: HEHLO, WOR
# D!neration 37: HEHLO, WOR
# Generation 38: HFyLO, WORLD!
# Generation 39: HEuLO, WORwD!
# Generation 40: HE0LO, WO|LD!
# Generation 41: HEHLO, WOR]D!
# Generation 42: HEHLO, WORJD!
# Generation 43: HEuLO, WOR]D!
# Generation 44: HEOLO, WOR*D!
# Generation 45: HE0LO, WORwD!
# Generation 46: HEHLO, WORhD!
# Generation 47: HE0LO, WORLD!
# Generation 48: HP0LO, WORLD!
# Generation 49: HEHLO, WOR]D!
# Generation 50: HEuLO, WORLD!
# Generation 51: HEYLO, WORLD!
# Generation 52: HEuLO, WORLD!
# Generation 53: HEuLO, WORLD!
# Generation 54: HE0LO, WORLD!
# Generation 55: HE0LO, WORLD!
# Generation 56: HEHLO, WORLD!
# Generation 57: HE0LO, WORLD!
# Generation 58: HE0LO, WORLD!
# Generation 59: HE0LO, WORLD!
# Generation 60: HE.LO, WORLD!
# Generation 61: HE0LO, WORLD!
# Generation 62: HE0LO, WORLD!
# Generation 63: HEyLO, WORLD!
# Generation 64: HE0LO, WORLD!
# Generation 65: HEbLO, WORLD!
# Generation 66: HEuLO, WORLD!
# Generation 67: HE0LO, WORLD!
# Generation 68: HE0LO, WORLD!
# Generation 69: HEbLO, WORLD!
# Generation 70: HE0LO, WORLD!
# Generation 71: HEHLO, WORLD!
# Generation 72: HE0LO, WORLD!
# Generation 73: HE0LO, WORLD!
# Generation 74: HEHLO, WORLD!
# Generation 75: HE0LO, WORLD!
# Generation 76: HEHLO, WORLD!
# Generation 77: HEHLO, WORLD!
# Generation 78: HEHLO, WORLD!
# Generation 79: HEHLO, WORLD!
# Generation 80: HE0LO, WORLD!
# Generation 81: HEHLO, WORLD!
# Generation 82: HE+LO, WORLD!
# Generation 83: HE0LO, WORLD!
# Generation 84: HE0LO, WORLD!
# Generation 85: HE0LO, WORLD!
# Generation 86: HEHLO, WORLD!
# Generation 87: HE0LO, WORLD!
# Generation 88: HE0LO, WORLD!
# Generation 89: HEwLO, WORLD!
# Generation 90: HELO, WORLD!
# Generation 91: HE0LO, WORLD!
# Generation 92: HEHLO, WORLD!
# Generation 93: HE]LO, WORLD!
# Generation 94: HELO, WORLD!
# Generation 95: HEHLO, WORLD!
# Generation 96: HEHLO, WORLD!
# Generation 97: HE0LO, WORLD!
# Generation 98: HELO, WORLD!
# Generation 99: HEHLO, WORLD!
# Generation 100: HEHLO, WORLD!
# Generation 101: HEHLO, WORLD!
# Generation 102: HE(LO, WORLD!
# Generation 103: HEHLO, WORLD!
# Generation 104: HE(LO, WORLD!
# Generation 105: HELO, WORLD!
# Generation 106: HE(LO, WORLD!
# Generation 107: HE(LO, WORLD!
# Generation 108: HE0LO, WORLD!
# Generation 109: HE]LO, WORLD!
# Generation 110: HE0LO, WORLD!
# Generation 111: HELO, WORLD!
# Generation 112: HE0LO, WORLD!
# Generation 113: HE0LO, WORLD!
# Generation 114: HELO, WORLD!
# Generation 115: HE0LO, WORLD!
# Generation 116: HEHLO, WORLD!
# Generation 117: HE0LO, WORLD!
# Generation 118: HE0LO, WORLD!
# Generation 119: HEHLO, WORLD!
# Generation 120: HELO, WORLD!
# Generation 121: HE(LO, WORLD!
# Generation 122: HE7LO, WORLD!
# Generation 123: HELLO, WORLD!
